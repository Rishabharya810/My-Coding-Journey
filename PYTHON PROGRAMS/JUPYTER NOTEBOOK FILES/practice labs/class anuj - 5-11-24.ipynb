# %%
from scipy.stats import binom
import matplotlib.pylpot as plt
# setting the values
# of n and p
n = 6
p = 0.6
# defining list of r values
r_values = list(range(n+1))
#list of pmf values
dist - [binom.pmf(r,n,p) for r in r_values]
# plotting the graph
plt.bar(r_valies, dist)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from scipy.stats import binom
#       2 import matplotlib.pylpot as plt
#       3 # setting the values
#       4 # of n and p
#
# ModuleNotFoundError: No module named 'scipy'

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

# Setting the values of n and p
n = 6
p = 0.6

# Defining list of r values
r_values = list(range(n+1))

# List of pmf values
dist = [binom.pmf(r, n, p) for r in r_values]

# Plotting the graph
plt.bar(r_values, dist)
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution (n=6, p=0.6)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from scipy.stats import binom
#       2 import matplotlib.pyplot as plt
#       4 # Setting the values of n and p
#
# ModuleNotFoundError: No module named 'scipy'

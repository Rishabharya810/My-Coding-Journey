# %%
class node:
    
  def _init_(self,coefficient,exponent):
    self.coefficient = coefficient
    self.exponent = exponent
    self.next = None

class PolynomialLinkedList:
  def _init_(self):
    self.head = None
  
  def add_term(self,coefficient,exponent):
    new_node = node(coefficient,exponent)
    
    # if the list is empty or if 
    if self.head is None or self.head.exp<exponent:

      self.head = new_node
    else:
        
      current = self.head

      
    # traverse the linked list to insert the node at the right position
      
    while current.next and current.next.exp > exponent:
        
      #current.next = new_node
        
      current = current.next
    if current.next and current.next.exp == exponent:
      current.next.coefficient += coefficient
    else:
      new_node.next = current.next
      current.next = new_node 

  def display(self):
    if not self.head:
      print('linked list is empty')
      return 

    current = self.head
    result = ''
    while current:
      if current.coefficient ! = 0:
        result += f'{current.coefficient}x^{current.exp}'
      if current.next and current.next.coeff >= 0:
        result += "+ "
        current = current.next
        
        print(result.strip())

polynomial = PolynomialLinkedList()
polynomial.add_term(3,2)


'''
    while current is not None or current.coefficient<coefficient:
      if
'''t
# Out:
#   Cell In[1], line 45
#     if current.coefficient ! = 0:
#                            ^
# SyntaxError: invalid syntax
